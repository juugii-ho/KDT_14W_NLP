# %%
import pandas as pd

hateDF = pd.read_csv('../data/hate.csv')
hateDF
# Out:
#                                                    text  \
# 0                                                     0
# 1     (현재 호텔주인 심정) 아18 난 마른하늘에 날벼락맞고 호텔망하게생겼는데 누군 계속...
# 2     ....한국적인 미인의 대표적인 분...너무나 곱고아름다운모습...그모습뒤의 슬픔을...
# 3     ...못된 넘들...남의 고통을 즐겼던 넘들..이젠 마땅한 처벌을 받아야지..,그래...
# 4                    1,2화 어설펐는데 3,4화 지나서부터는 갈수록 너무 재밌던데
# ...                                                 ...
# 7892                                      힘내세요~ 응원합니다!!
# 7893                             힘내세요~~삼가 고인의 명복을 빕니다..
# 7894                              힘내세용 ^^ 항상 응원합니닷 ^^ !
# 7895  힘내소...연기로 답해요.나도 53살 인데 이런일 저런일 다 있더라구요.인격을 믿습...
# 7896                                 힘들면 관뒀어야지 그게 현명한거다
#
#                                                   title gender_bias    bias  \
# 0                                                     0           0       0
# 1              "밤새 조문 행렬…故 전미선, 동료들이 그리워하는 따뜻한 배우 [종합]"       False  others
# ...

# %% [markdown]
# #### [2-3] 토큰화

# %%
from konlpy.tag import Okt

# %%
# 형태소 분석기 인스턴스 생성
okt = Okt()

# %%
documentDF.document.str.str.cat()
